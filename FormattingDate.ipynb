# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisPalominoR/Clase-5/blob/main/FormattingDate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://i.imgur.com/6U6q5jQ.png"/>
#
# # Formatting Dates in Python
#
# It is very common to find dates (some combination of year, month, day of week and time) in data that is collected in real time (and other that organize event information.
#
# Let's see a data frame that comes with dates from an API.

# %%
# !pip install sodapy
# Out:
# Requirement already satisfied: sodapy in /usr/local/lib/python3.10/dist-packages (2.2.0)
# Requirement already satisfied: requests>=2.28.1 in /usr/local/lib/python3.10/dist-packages (from sodapy) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28.1->sodapy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28.1->sodapy) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28.1->sodapy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28.1->sodapy) (2024.2.2)

# %%
import pandas as pd
from sodapy import Socrata

client = Socrata("data.seattle.gov", None)

results = client.get("kzjm-xkqj", limit=2000)

# Convert to pandas DataFrame
calls911 = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %% [markdown]
# Let's check the data types:

# %%
calls911.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   address                      2000 non-null   object
#  1   type                         2000 non-null   object
#  2   datetime                     2000 non-null   object
#  3   latitude                     2000 non-null   object
#  4   longitude                    2000 non-null   object
#  5   report_location              2000 non-null   object
#  6   incident_number              2000 non-null   object
#  7   :@computed_region_ru88_fbhk  1995 non-null   object
#  8   :@computed_region_kuhn_3gp2  1995 non-null   object
#  9   :@computed_region_q256_3sug  2000 non-null   object
#  10  :@computed_region_2day_rhn5  164 non-null    object
#  11  :@computed_region_cyqu_gs94  152 non-null    object
# dtypes: object(12)
# memory usage: 187.6+ KB

# %% [markdown]
# Let's get rid of some columns:

# %%
calls911=calls911.iloc[:,:7]

# %% [markdown]
# Let's check the column _datetime_:

# %%
calls911.datetime.head()
# Out:
# 0    2024-02-13T07:39:00.000
# 1    2024-02-13T07:26:00.000
# 2    2024-02-13T07:24:00.000
# 3    2024-02-13T07:20:00.000
# 4    2024-02-13T07:20:00.000
# Name: datetime, dtype: object

# %%
# verify data type
type(calls911.datetime[0])
# Out:
# str

# %% [markdown]
# The date and time information is not useful at this time, that is, the information it offers is of limited use, as it is just a string.
#
# Let's make it useful:

# %%
calls911.datetime=pd.to_datetime(calls911.datetime)
calls911.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   address          2000 non-null   object
#  1   type             2000 non-null   object
#  2   datetime         2000 non-null   datetime64[ns]
#  3   latitude         2000 non-null   object
#  4   longitude        2000 non-null   object
#  5   report_location  2000 non-null   object
#  6   incident_number  2000 non-null   object
# dtypes: datetime64[ns](1), object(6)
# memory usage: 109.5+ KB

# %%
calls911
# Out:
#                        address                         type  \
# 0     3rd Ave S / S Jackson St               Medic Response
# 1           6020 Rainier Ave S  AFA4 - Auto Alarm 2 + 1 + 1
# 2                 2209 1st Ave   Medic Response- 7 per Rule
# 3           6203 RAINIER AVE S             Fire in Building
# 4             2711 Ne 115th St                 Aid Response
# ...                        ...                          ...
# 1995             538 1st Ave S   Automatic Fire Alarm False
# 1996          4505 42nd Ave Sw             Triaged Incident
# 1997          800 Jefferson St          Low Acuity Response
# 1998                110 Lee St             Triaged Incident
# 1999          7008 42nd Ave Ne               Medic Response
#
#                 datetime   latitude    longitude  \
# 0    2024-02-13 07:39:00  47.599199  -122.330276
# 1    2024-02-13 07:26:00  47.548241  -122.276873
# 2    2024-02-13 07:24:00  47.612669  -122.345319
# 3    2024-02-13 07:20:00  47.546661  -122.276539
# 4    2024-02-13 07:20:00   47.71204  -122.299292
# ...                  ...        ...          ...
# 1995 2024-02-07 12:30:00  47.597242  -122.334192
# 1996 2024-02-07 12:14:00   47.56283  -122.385455
# 1997 2024-02-07 12:10:00  47.604377  -122.325207
# 1998 2024-02-07 12:08:00     47.631    -122.3554
# 1999 2024-02-07 12:03:00  47.679467  -122.283879
#
#                                         report_location incident_number
# 0     {'type': 'Point', 'coordinates': [-122.330276,...      F240022216
# 1     {'type': 'Point', 'coordinates': [-122.276873,...      F240022213
# 2     {'type': 'Point', 'coordinates': [-122.345319,...      F240022212
# 3     {'type': 'Point', 'coordinates': [-122.276539,...      F240022208
# 4     {'type': 'Point', 'coordinates': [-122.299292,...      F240022207
# ...                                                 ...             ...
# 1995  {'type': 'Point', 'coordinates': [-122.334192,...      F240019602
# 1996  {'type': 'Point', 'coordinates': [-122.385455,...      F240019598
# 1997  {'type': 'Point', 'coordinates': [-122.325207,...      F240019597
# 1998  {'type': 'Point', 'coordinates': [-122.3554, 4...      F240019596
# 1999  {'type': 'Point', 'coordinates': [-122.283879,...      F240019595
#
# [2000 rows x 7 columns]

# %% [markdown]
# Once you have this data type, you can retrieve important information:

# %%
calls911['date']=calls911.datetime.dt.date
calls911['year']=calls911.datetime.dt.year
calls911['month']=calls911.datetime.dt.month_name()
calls911['weekday']=calls911.datetime.dt.day_name()
calls911['hour']=calls911.datetime.dt.hour

# %%
calls911.head()
# Out:
#                     address                         type            datetime  \
# 0  3rd Ave S / S Jackson St               Medic Response 2024-02-13 07:39:00
# 1        6020 Rainier Ave S  AFA4 - Auto Alarm 2 + 1 + 1 2024-02-13 07:26:00
# 2              2209 1st Ave   Medic Response- 7 per Rule 2024-02-13 07:24:00
# 3        6203 RAINIER AVE S             Fire in Building 2024-02-13 07:20:00
# 4          2711 Ne 115th St                 Aid Response 2024-02-13 07:20:00
#
#     latitude    longitude                                    report_location  \
# 0  47.599199  -122.330276  {'type': 'Point', 'coordinates': [-122.330276,...
# 1  47.548241  -122.276873  {'type': 'Point', 'coordinates': [-122.276873,...
# 2  47.612669  -122.345319  {'type': 'Point', 'coordinates': [-122.345319,...
# 3  47.546661  -122.276539  {'type': 'Point', 'coordinates': [-122.276539,...
# 4   47.71204  -122.299292  {'type': 'Point', 'coordinates': [-122.299292,...
#
#   incident_number        date  year     month  weekday  hour
# 0      F240022216  2024-02-13  2024  February  Tuesday     7
# 1      F240022213  2024-02-13  2024  February  Tuesday     7
# 2      F240022212  2024-02-13  2024  February  Tuesday     7
# 3      F240022208  2024-02-13  2024  February  Tuesday     7
# 4      F240022207  2024-02-13  2024  February  Tuesday     7

# %% [markdown]
# Let's create a new column with what we have. In this case, a boolean where you tell if it is night time (after 8 pm before 6 am):

# %%
calls911['nightTime']=((calls911['hour']<=6) | (calls911['hour']>=20))

#here

calls911.head()
# Out:
#                     address                         type            datetime  \
# 0  3rd Ave S / S Jackson St               Medic Response 2024-02-13 07:39:00
# 1        6020 Rainier Ave S  AFA4 - Auto Alarm 2 + 1 + 1 2024-02-13 07:26:00
# 2              2209 1st Ave   Medic Response- 7 per Rule 2024-02-13 07:24:00
# 3        6203 RAINIER AVE S             Fire in Building 2024-02-13 07:20:00
# 4          2711 Ne 115th St                 Aid Response 2024-02-13 07:20:00
#
#     latitude    longitude                                    report_location  \
# 0  47.599199  -122.330276  {'type': 'Point', 'coordinates': [-122.330276,...
# 1  47.548241  -122.276873  {'type': 'Point', 'coordinates': [-122.276873,...
# 2  47.612669  -122.345319  {'type': 'Point', 'coordinates': [-122.345319,...
# 3  47.546661  -122.276539  {'type': 'Point', 'coordinates': [-122.276539,...
# 4   47.71204  -122.299292  {'type': 'Point', 'coordinates': [-122.299292,...
#
#   incident_number        date  year     month  weekday  hour  nightTime
# 0      F240022216  2024-02-13  2024  February  Tuesday     7      False
# 1      F240022213  2024-02-13  2024  February  Tuesday     7      False
# 2      F240022212  2024-02-13  2024  February  Tuesday     7      False
# 3      F240022208  2024-02-13  2024  February  Tuesday     7      False
# 4      F240022207  2024-02-13  2024  February  Tuesday     7      False

# %% [markdown]
# Let's save what we have:

# %%
import os

calls911.to_pickle(os.path.join('DataFiles','calls911.pkl'))

# %% [markdown]
# What about data that comes in Spanish?

# %%
#!pip install bs4

# %%
link="https://es.wikipedia.org/wiki/Pandemia_de_COVID-19"

import pandas as pd

covid=pd.read_html(link, flavor="bs4", attrs={"class":"wikitable sortable"})

# %% [markdown]
# Let me keep the second df:

# %%
covidDF=covid[1].copy()
covidDF
# Out:
#            Territorios   Territorios.1  \
# 0              Bérgamo          Italia
# 1              Ginebra           Suiza
# 2               España          Europa
# 3            Karnataka           India
# 4               México         América
# 5          Nueva Delhi           India
# 6  Nueva York (ciudad)  Estados Unidos
# 7  Nueva York (estado)  Estados Unidos
# 8          Reino Unido          Europa
#
#                           Fecha del análisis Porcentaje con anticuerpos  \
# 0   23 de abril de 2020 a 3 de junio de 2020                        57%
# 1     6 de abril de 2020 a 9 de mayo de 2020                      10,9%
# 2                    15 de diciembre de 2020                       9,9%
# 3                   16 de septiembre de 2020                      27,3%
# 4                    16 de diciembre de 2020                      25,0%
# 5  27 de junio de 2020 a 10 de julio de 2020                      23,5%
# 6  19 de abril de 2020 a 28 de abril de 2020                      22,7%
# 7  19 de abril de 2020 a 28 de abril de 2020                        14%
# 8                          noviembre de 2020                       8,8%
#
#   Personas que han sido infectadas     Referencia
# 0                          635 000         [123]​
# 1                           54 000  [124]​ [125]​
# 2                        4 700 000         [126]​
# 3                       19 300 000         [127]​
# 4                       32 000 000         [128]​
# 5                        5 111 000         [129]​
# 6                        1 907 000  [130]​ [125]​
# 7                        2 139 000         [130]​
# 8                        5 900 000         [131]​

# %% [markdown]
# Notice the presence of some non-English punctuation:

# %%
covidDF.columns
# Out:
# Index(['Territorios', 'Territorios.1', 'Fecha del análisis',
#        'Porcentaje con anticuerpos', 'Personas que han sido infectadas',
#        'Referencia'],
#       dtype='object')

# %% [markdown]
# Let's get rid of those:

# %%
# !pip install unidecode
# Out:
# Requirement already satisfied: unidecode in /usr/local/lib/python3.10/dist-packages (1.3.8)

# %%
import unidecode as ud

[ud.unidecode(c) for c in covidDF.columns]
# Out:
# ['Territorios',
#  'Territorios.1',
#  'Fecha del analisis',
#  'Porcentaje con anticuerpos',
#  'Personas que han sido infectadas',
#  'Referencia']

# %%
#or
import re

[re.sub('\\s','',ud.unidecode(c)) for c in covidDF.columns]
# Out:
# ['Territorios',
#  'Territorios.1',
#  'Fechadelanalisis',
#  'Porcentajeconanticuerpos',
#  'Personasquehansidoinfectadas',
#  'Referencia']

# %%
#then
covidDF.columns=[re.sub('\\s','',ud.unidecode(c)) for c in covidDF.columns]

# %% [markdown]
# Let's  focus on the _Fechadelanalisis_ column:

# %%
# use " a " to split:
covidDF.Fechadelanalisis.str.split(" a ",expand=True)
# Out:
#                           0                    1
# 0       23 de abril de 2020   3 de junio de 2020
# 1        6 de abril de 2020    9 de mayo de 2020
# 2   15 de diciembre de 2020                 None
# 3  16 de septiembre de 2020                 None
# 4   16 de diciembre de 2020                 None
# 5       27 de junio de 2020  10 de julio de 2020
# 6       19 de abril de 2020  28 de abril de 2020
# 7       19 de abril de 2020  28 de abril de 2020
# 8         noviembre de 2020                 None

# %%
# create the two columns

covidDF[["fecha1","fecha2"]]=covidDF.Fechadelanalisis.str.split(" a ",expand=True)
covidDF
# Out:
#            Territorios   Territorios.1  \
# 0              Bérgamo          Italia
# 1              Ginebra           Suiza
# 2               España          Europa
# 3            Karnataka           India
# 4               México         América
# 5          Nueva Delhi           India
# 6  Nueva York (ciudad)  Estados Unidos
# 7  Nueva York (estado)  Estados Unidos
# 8          Reino Unido          Europa
#
#                             Fechadelanalisis Porcentajeconanticuerpos  \
# 0   23 de abril de 2020 a 3 de junio de 2020                      57%
# 1     6 de abril de 2020 a 9 de mayo de 2020                    10,9%
# 2                    15 de diciembre de 2020                     9,9%
# 3                   16 de septiembre de 2020                    27,3%
# 4                    16 de diciembre de 2020                    25,0%
# 5  27 de junio de 2020 a 10 de julio de 2020                    23,5%
# 6  19 de abril de 2020 a 28 de abril de 2020                    22,7%
# 7  19 de abril de 2020 a 28 de abril de 2020                      14%
# 8                          noviembre de 2020                     8,8%
#
#   Personasquehansidoinfectadas     Referencia                    fecha1  \
# 0                      635 000         [123]​       23 de abril de 2020
# 1                       54 000  [124]​ [125]​        6 de abril de 2020
# 2                    4 700 000         [126]​   15 de diciembre de 2020
# 3                   19 300 000         [127]​  16 de septiembre de 2020
# 4                   32 000 000         [128]​   16 de diciembre de 2020
# 5                    5 111 000         [129]​       27 de junio de 2020
# 6                    1 907 000  [130]​ [125]​       19 de abril de 2020
# 7                    2 139 000         [130]​       19 de abril de 2020
# 8                    5 900 000         [131]​         noviembre de 2020
#
#                 fecha2
# 0   3 de junio de 2020
# 1    9 de mayo de 2020
# 2                 None
# 3                 None
# 4                 None
# 5  10 de julio de 2020
# 6  28 de abril de 2020
# 7  28 de abril de 2020
# 8                 None

# %% [markdown]
# Let's format one of those columns:

# %%
covidDF.fecha1
# Out:
# 0         23 de abril de 2020
# 1          6 de abril de 2020
# 2     15 de diciembre de 2020
# 3    16 de septiembre de 2020
# 4     16 de diciembre de 2020
# 5         27 de junio de 2020
# 6         19 de abril de 2020
# 7         19 de abril de 2020
# 8           noviembre de 2020
# Name: fecha1, dtype: object

# %%
covidDF.loc[8,'fecha1']='1 de noviembre de 2020'

# %%
# let's split again:

covidDF.fecha1.str.split(" de ",expand=True)
# Out:
#     0           1     2
# 0  23       abril  2020
# 1   6       abril  2020
# 2  15   diciembre  2020
# 3  16  septiembre  2020
# 4  16   diciembre  2020
# 5  27       junio  2020
# 6  19       abril  2020
# 7  19       abril  2020
# 8   1   noviembre  2020

# %% [markdown]
# I could create three new columns:

# %%
covidDF[['fecha1_dia','fecha1_mes','fecha1_anho']]=covidDF.fecha1.str.split(" de ",expand=True)
covidDF[['fecha1_dia','fecha1_mes','fecha1_anho']]
# Out:
#   fecha1_dia  fecha1_mes fecha1_anho
# 0         23       abril        2020
# 1          6       abril        2020
# 2         15   diciembre        2020
# 3         16  septiembre        2020
# 4         16   diciembre        2020
# 5         27       junio        2020
# 6         19       abril        2020
# 7         19       abril        2020
# 8          1   noviembre        2020

# %% [markdown]
# We should use the month number instead of name. Let's prepare a dict of changes:

# %%
monthName=('enero','febrero','marzo','abril','mayo','junio','julio','agosto','septiembre','octubre','noviembre','diciembre')
changes={name:number for name,number in zip(monthName,range(1,len(monthName)+1))}
changes
# Out:
# {'enero': 1,
#  'febrero': 2,
#  'marzo': 3,
#  'abril': 4,
#  'mayo': 5,
#  'junio': 6,
#  'julio': 7,
#  'agosto': 8,
#  'septiembre': 9,
#  'octubre': 10,
#  'noviembre': 11,
#  'diciembre': 12}

# %%
covidDF.fecha1_mes.replace(changes,inplace=True)

# %% [markdown]
# Now we have:

# %%
covidDF[['fecha1_dia','fecha1_mes','fecha1_anho']]
# Out:
#   fecha1_dia  fecha1_mes fecha1_anho
# 0         23           4        2020
# 1          6           4        2020
# 2         15          12        2020
# 3         16           9        2020
# 4         16          12        2020
# 5         27           6        2020
# 6         19           4        2020
# 7         19           4        2020
# 8          1          11        2020

# %% [markdown]
# We will use those columns to create a date:

# %%
pd.to_datetime(dict(year=covidDF.fecha1_anho, month=covidDF.fecha1_mes, day=covidDF.fecha1_dia))
# Out:
# 0   2020-04-23
# 1   2020-04-06
# 2   2020-12-15
# 3   2020-09-16
# 4   2020-12-16
# 5   2020-06-27
# 6   2020-04-19
# 7   2020-04-19
# 8   2020-11-01
# dtype: datetime64[ns]

# %%
# creating the column
covidDF['newDate']=pd.to_datetime(dict(year=covidDF.fecha1_anho, month=covidDF.fecha1_mes, day=covidDF.fecha1_dia))

# so far
covidDF.head()
# Out:
#   Territorios Territorios.1                          Fechadelanalisis  \
# 0     Bérgamo        Italia  23 de abril de 2020 a 3 de junio de 2020
# 1     Ginebra         Suiza    6 de abril de 2020 a 9 de mayo de 2020
# 2      España        Europa                   15 de diciembre de 2020
# 3   Karnataka         India                  16 de septiembre de 2020
# 4      México       América                   16 de diciembre de 2020
#
#   Porcentajeconanticuerpos Personasquehansidoinfectadas     Referencia  \
# 0                      57%                      635 000         [123]​
# 1                    10,9%                       54 000  [124]​ [125]​
# 2                     9,9%                    4 700 000         [126]​
# 3                    27,3%                   19 300 000         [127]​
# 4                    25,0%                   32 000 000         [128]​
#
#                      fecha1              fecha2 fecha1_dia  fecha1_mes  \
# 0       23 de abril de 2020  3 de junio de 2020         23           4
# 1        6 de abril de 2020   9 de mayo de 2020          6           4
# 2   15 de diciembre de 2020                None         15          12
# 3  16 de septiembre de 2020                None         16           9
# 4   16 de diciembre de 2020                None         16          12
#
#   fecha1_anho    newDate
# 0        2020 2020-04-23
# 1        2020 2020-04-06
# 2        2020 2020-12-15
# 3        2020 2020-09-16
# 4        2020 2020-12-16

# %%
# data types
covidDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Territorios                   9 non-null      object
#  1   Territorios.1                 9 non-null      object
#  2   Fechadelanalisis              9 non-null      object
#  3   Porcentajeconanticuerpos      9 non-null      object
#  4   Personasquehansidoinfectadas  9 non-null      object
#  5   Referencia                    9 non-null      object
#  6   fecha1                        9 non-null      object
#  7   fecha2                        5 non-null      object
#  8   fecha1_dia                    9 non-null      object
#  9   fecha1_mes                    9 non-null      int64
#  10  fecha1_anho                   9 non-null      object
#  11  newDate                       9 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 992.0+ bytes

# %% [markdown]
# Note the presence of numeric columns:

# %%
covidDF.loc[:,['Porcentajeconanticuerpos','Personasquehansidoinfectadas']]
# Out:
#   Porcentajeconanticuerpos Personasquehansidoinfectadas
# 0                      57%                      635 000
# 1                    10,9%                       54 000
# 2                     9,9%                    4 700 000
# 3                    27,3%                   19 300 000
# 4                    25,0%                   32 000 000
# 5                    23,5%                    5 111 000
# 6                    22,7%                    1 907 000
# 7                      14%                    2 139 000
# 8                     8,8%                    5 900 000

# %% [markdown]
# Let's clean and **format**:

# %%
covidDF[['Porcentajeconanticuerpos','Personasquehansidoinfectadas']]=covidDF.iloc[:,[3,4]].replace('\\%|\\s',"",regex=True).replace(',','.',regex=True)
covidDF[['Porcentajeconanticuerpos','Personasquehansidoinfectadas']]
# Out:
#   Porcentajeconanticuerpos Personasquehansidoinfectadas
# 0                       57                       635000
# 1                     10.9                        54000
# 2                      9.9                      4700000
# 3                     27.3                     19300000
# 4                     25.0                     32000000
# 5                     23.5                      5111000
# 6                     22.7                      1907000
# 7                       14                      2139000
# 8                      8.8                      5900000

# %%
#but
covidDF[['Porcentajeconanticuerpos','Personasquehansidoinfectadas']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 2 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Porcentajeconanticuerpos      9 non-null      object
#  1   Personasquehansidoinfectadas  9 non-null      object
# dtypes: object(2)
# memory usage: 272.0+ bytes

# %% [markdown]
# They are clean, but need the data type change:

# %%
covidDF[['Porcentajeconanticuerpos','Personasquehansidoinfectadas']]=covidDF.iloc[:,[3,4]].apply(lambda x: pd.to_numeric(x))

# %%
covidDF[['Porcentajeconanticuerpos','Personasquehansidoinfectadas']]
# Out:
#    Porcentajeconanticuerpos  Personasquehansidoinfectadas
# 0                      57.0                        635000
# 1                      10.9                         54000
# 2                       9.9                       4700000
# 3                      27.3                      19300000
# 4                      25.0                      32000000
# 5                      23.5                       5111000
# 6                      22.7                       1907000
# 7                      14.0                       2139000
# 8                       8.8                       5900000

# %% [markdown]
# Now we got it:

# %%
covidDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Territorios                   9 non-null      object
#  1   Territorios.1                 9 non-null      object
#  2   Fechadelanalisis              9 non-null      object
#  3   Porcentajeconanticuerpos      9 non-null      float64
#  4   Personasquehansidoinfectadas  9 non-null      int64
#  5   Referencia                    9 non-null      object
#  6   fecha1                        9 non-null      object
#  7   fecha2                        5 non-null      object
#  8   fecha1_dia                    9 non-null      object
#  9   fecha1_mes                    9 non-null      int64
#  10  fecha1_anho                   9 non-null      object
#  11  newDate                       9 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(2), object(8)
# memory usage: 992.0+ bytes

# %% [markdown]
# Dates as strings are in general translated in pandas (best guess):

# %%
date='20240113'
pd.to_datetime(date)
# Out:
# Timestamp('2024-01-13 00:00:00')

# %% [markdown]
# But remember the symbols for dates, in case you need them:

# %%
date='12112023'
pd.to_datetime(date,format='%d%m%Y')
# Out:
# Timestamp('2023-11-12 00:00:00')

# %%
date='12nov2023'
pd.to_datetime(date,format='%d%b%Y')
# Out:
# Timestamp('2023-11-12 00:00:00')

# %%
date='NOVEMBER122023'
pd.to_datetime(date,format='%B%d%Y')
# Out:
# Timestamp('2023-11-12 00:00:00')

# %%
date='NOVEMBER1223'
pd.to_datetime(date,format='%B%d%y')
# Out:
# Timestamp('2023-11-12 00:00:00')

# %% [markdown]
# Keep this [link](https://docs.safe.com/fme/2017.0/html/FME_Desktop_Documentation/FME_Transformers_HelpPane/Transformers/dateformatter.htm) for reference.
